# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

chi2 = np.asarray([0.2,0.1,0.2])
G = np.asarray([0.1, 0.5, 1.0])

like = np.exp(-1./2 * chi2)

fig = plt.figure()
ax = plt.subplot()

ax.plot(G, like)
plt.show()
